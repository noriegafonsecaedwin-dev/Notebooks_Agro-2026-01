# %% [markdown]
# <a href="https://colab.research.google.com/github/noriegafonsecaedwin-dev/Notebooks_Agro-2026-01/blob/main/Rendimiento_Extraccion_aceite.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Control de rendimiento de extraccion de aceite**
#
# Este ejercicio es ideal para introducir float, int y la concatenación de strings.
#
# **Planteamiento:**
# Una planta procesadora de palma de aceite necesita calcular el Índice de Rendimiento de Extracción (IRE). El operario debe ingresar el peso total de los racimos de fruta fresca (RFF) procesados en kilogramos y la cantidad de aceite crudo obtenido en litros.
#
# **Requerimientos:**
#
# 1. Solicitar el nombre del lote de producción (Tipo string).
# 2. Solicitar el peso de los racimos en kg (Tipo float). (Pr)
# 3. Solicitar los litros de aceite obtenidos (Tipo float). (Lt)
# 4. Calcular el rendimiento sabiendo que la densidad aproximada del aceite es de 0.92 kg/L. (r)
#
# $$Pa=Lt * 0.92
# $$
#  $$r=(Pa/Pr) * 100$$
#
# **Prueba del programa:**
#
# Si se ingresan 1000 kg de racimos y se obtienen 200 litros de aceite, el programa debe informar que el rendimiento del lote es del 18.4%.

# %%
# ENTRADA: Solicitar el nombre del lote de producción (Tipo string).
# Solicitar el peso de los racimos en kg (Tipo float). (Pr)
# Solicitar los litros de aceite obtenidos (Tipo float). (Lt)
nombre_lote = input("Ingrese el nombre del lote: ")
Pr = float(input("Ingrese el peso de los racimos en kg: "))
Lt = float(input("Ingrese la cantidad de aceite crudo obtenido en litros: "))

# PROCESO: calcular peso del aceite (Pa) y el rendimiento (r)
Pa = Lt * 0.92
r = (Pa / Pr) * 100
#SALIDA: informar el rendimiento del lote
print("El rendimiento del lote es: ", r)
# Out:
# Ingrese el nombre del lote: Puerta Verde
# Ingrese el peso de los racimos en kg: 1000
# Ingrese la cantidad de aceite crudo obtenido en litros: 200
# El rendimiento del lote es:  18.4

# %% [markdown]
# El código proporcionado en la celda `G8f6k5jIQDwT` realiza los siguientes pasos para calcular el Índice de Rendimiento de Extracción (IRE):
#
# ```python
# # ENTRADA: Solicitar el nombre del lote de producción (Tipo string).
# # Solicitar el peso de los racimos en kg (Tipo float). (Pr)
# # Solicitar los litros de aceite obtenidos (Tipo float). (Lt)
# ```
# Estas líneas son comentarios que describen las próximas acciones: solicitar al usuario el nombre del lote, el peso de los racimos en kilogramos (Pr) y los litros de aceite obtenidos (Lt).
#
# ```python
# nombre_lote = input("Ingrese el nombre del lote: ")
# ```
# Esta línea utiliza la función `input()` para pedir al usuario que introduzca el nombre del lote de producción. El valor ingresado se almacena en la variable `nombre_lote` como una cadena de texto (string).
#
# ```python
# Pr = float(input("Ingrese el peso de los racimos en kg: "))
# ```
# Esta línea solicita al usuario el peso de los racimos en kilogramos. La función `input()` lee la entrada como una cadena, y `float()` la convierte a un número de coma flotante (float) para poder realizar cálculos decimales. El resultado se guarda en la variable `Pr`.
#
# ```python
# Lt = float(input("Ingrese la cantidad de aceite crudo obtenido en litros: "))
# ```
# Similar a la línea anterior, esta línea pide al usuario la cantidad de aceite crudo obtenido en litros. La entrada se convierte a un número de coma flotante y se almacena en la variable `Lt`.
#
# ```python
# # PROCESO: calcular peso del aceite (Pa) y el rendimiento (r)
# ```
# Este comentario indica que las siguientes líneas realizarán los cálculos necesarios.
#
# ```python
# Pa = Lt * 0.92
# ```
# Aquí se calcula el peso del aceite (`Pa`). Se multiplica la cantidad de litros de aceite (`Lt`) por su densidad aproximada (0.92 kg/L). El resultado es el peso del aceite en kilogramos.
#
# ```python
# r = (Pa / Pr) * 100
# ```
# Esta línea calcula el Índice de Rendimiento de Extracción (`r`). Se divide el peso del aceite (`Pa`) entre el peso total de los racimos (`Pr`) y el resultado se multiplica por 100 para expresarlo como un porcentaje.
#
# ```python
# #SALIDA: informar el rendimiento del lote
# ```
# Este comentario señala que la siguiente línea mostrará el resultado al usuario.
#
# ```python
# print("El rendimiento del lote es: ", r)
# ```
# Finalmente, esta línea imprime el resultado en la consola, mostrando el mensaje "El rendimiento del lote es: " seguido del valor calculado de `r` (el rendimiento porcentual).
